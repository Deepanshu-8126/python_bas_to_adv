# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepanshu-8126/python_bas_to_adv/blob/main/python_revision_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Even and Odd Checker

# %%
# check a number is odd or even
n=int(input("Enter an number"))
if n%2==0:
  print("Even number")
else:
  print("Odd number")
# Out:
# Enter an number3
# Odd number

# %%
# Reverse a string
s =  "Python"
print(s[::-1])
# Out:
# nohtyP

# %%
# factorial number
n=int(input("Enter number "))
fact=1
for i in range(1,n+1):
   fact=fact*i
print(fact)
# Out:
# Enter number 3
# 6

# %%
# swap without third variable and third variable
a=int(input("Enter number "))
b=int(input("Enter second number "))
a,b=b,a
print(f"Vaalue of a is {a}")
print(f"Value of b is {b}")
# Out:
# Enter number 3
# Enter second number 1
# Vaalue of a is 1
# Value of b is 3

# %%
# Plandriome number  check
n=int(input("Enter number "))
if str(n)==str(n)[::-1]:
  print("Plandriome number")
else:
  print("Not a plandriome number")
# Out:
# Enter number 121
# Plandriome number
